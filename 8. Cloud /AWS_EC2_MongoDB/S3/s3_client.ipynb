# %% [markdown]
# ## Python script using Boto3 to interact with Amazon S3.

# %% [markdown]
# `Boto3` allows you to programatically interact with AWS services
# `S3 - Simple Storage Service` - Amazon's clour storage solution.

# %%
import boto3
import pprint as pp        # pprint - pretty print displays comples data in a nicely formatted way

# Let's use Amazon S3
s3_resource = boto3.resource('s3')
s3_client = boto3.client('s3')

# %% [markdown]
# `s3_resource` - creates resource-level object for S3. It uses a higher-level abstraction giving access to classes like `Bucket`, `Object`

# %% [markdown]
# `s3_client` - creates a client-level object for S3. It's lower-level, and gives access to raw AWS API methods (`list_buckets`,`get_object`, etc)

# %% [markdown]
# ### S3 RESOURCE BUCKETS

# %%
# S3 RESOURCE - OBJECT ORIENTED allows you to interact with BUCKETS and OBJECT classes, not just RAW data
for bucket in s3_resource.buckets.all():
    print(bucket.name)
# Out:
# assessment-dispatcher
# assessment-dispatcher-test
# assessmentbackup
# aws-logs-135928476890-eu-central-1
# bulk-policy-migration-135928476890
# cloudfuntest
# cyber10x-group1-bucket
# data-402-final-project
# data-eng-401-final-project
# data-eng-project-master
# data-eng-resources
# data-preassignment-alien-project-group1
# devops-bootcamp-shahrukh
# devops-content
# elasticbeanstalk-eu-west-1-135928476890
# emiledevopstest556373
# eng130-videos
# florina-hmrc-remote-backend
# graduate-market-analysis
# imc.spartaglobal.academy
# iotdatajoy2023
# jenkins-build-test
# kaki-udemy
# kaki-work-space
# profiles.spartaglobal.academy
# shahrukhterraformremotebackend
# sparta-backups
# sparta-cyber-bucket
# sparta-data
# sparta-example-state
# sparta-marketing
# sparta-media
# sparta-profiles
# sparta-terraform-state
# tech230-ramon1
# udemy-lab-streaming-data-rahul

# %% [markdown]
# ### S3 CLIENT BUCKETS

# %%
# S3 CLIENT - EXPLICIT - Provides DIRECT access to AWS services via RAW API Calls
bucket_list = s3_client.list_buckets()
pp.pprint(bucket_list)

for bucket in bucket_list['Buckets']:
    print(bucket['Name'])
# Out:
# {'Buckets': [{'CreationDate': datetime.datetime(2024, 11, 9, 3, 20, 37, tzinfo=tzutc()),
#               'Name': 'assessment-dispatcher'},
#              {'CreationDate': datetime.datetime(2024, 11, 12, 6, 55, 36, tzinfo=tzutc()),
#               'Name': 'assessment-dispatcher-test'},
#              {'CreationDate': datetime.datetime(2024, 11, 9, 3, 20, 42, tzinfo=tzutc()),
#               'Name': 'assessmentbackup'},
#              {'CreationDate': datetime.datetime(2024, 11, 12, 8, 20, 9, tzinfo=tzutc()),
#               'Name': 'aws-logs-135928476890-eu-central-1'},
#              {'CreationDate': datetime.datetime(2024, 9, 16, 9, 35, 28, tzinfo=tzutc()),
#               'Name': 'bulk-policy-migration-135928476890'},
#              {'CreationDate': datetime.datetime(2024, 12, 10, 16, 25, 1, tzinfo=tzutc()),
#               'Name': 'cloudfuntest'},
#              {'CreationDate': datetime.datetime(2024, 10, 30, 23, 26, 42, tzinfo=tzutc()),
#               'Name': 'cyber10x-group1-bucket'},
#              {'CreationDate': datetime.datetime(2024, 11, 9, 11, 41, 18, tzinfo=tzutc()),
#               'Name': 'data-402-final-project'},
#              {'CreationDate': datetime.datetime(2024, 11, 12, 17, 25, 9, tzinfo=tzutc()),
#               'Name': 'data-eng-401-final-project'},
#              {'CreationDate': datetime.datetime(2024, 11, 9, 11, 42, 22, tzinfo=tzutc()),
#               'Name': 'data-eng-project-master'},
#              {'CreationDate': datetime.datetime(2024, 11, 9, 11, 42, 22, tzinfo=tzutc()),
#               'Name': 'data-eng-resources'},
#              {'CreationDate': datetime.datetime(2024, 11, 12, 17, 26, 21, tzinfo=tzutc()),
#               'Name': 'data-preassignment-alien-project-group1'},
#              {'CreationDate': datetime.datetime(2024, 10, 31, 0, 35, 20, tzinfo=tzutc()),
#               'Name': 'devops-bootcamp-shahrukh'},
#              {'CreationDate': datetime.datetime(2024, 11, 12, 20, 50, 50, tzinfo=tzutc()),
#               'Name': 'devops-content'},
#              {'CreationDate': datetime.datetime(2024, 10, 31, 1, 11, 9, tzinfo=tzutc()),
#               'Name': 'elasticbeanstalk-eu-west-1-135928476890'},
#              {'CreationDate': datetime.datetime(2024, 10, 31, 1, 24, 37, tzinfo=tzutc()),
#               'Name': 'emiledevopstest556373'},
#              {'CreationDate': datetime.datetime(2024, 10, 31, 1, 26, 34, tzinfo=tzutc()),
#               'Name': 'eng130-videos'},
#              {'CreationDate': datetime.datetime(2024, 10, 31, 1, 57, 8, tzinfo=tzutc()),
#               'Name': 'florina-hmrc-remote-backend'},
#              {'CreationDate': datetime.datetime(2024, 11, 8, 1, 48, 37, tzinfo=tzutc()),
#               'Name': 'graduate-market-analysis'},
#              {'CreationDate': datetime.datetime(2024, 11, 9, 22, 24, 3, tzinfo=tzutc()),
#               'Name': 'imc.spartaglobal.academy'},
#              {'CreationDate': datetime.datetime(2024, 11, 9, 22, 44, 8, tzinfo=tzutc()),
#               'Name': 'iotdatajoy2023'},
#              {'CreationDate': datetime.datetime(2024, 11, 9, 23, 2, 6, tzinfo=tzutc()),
#               'Name': 'jenkins-build-test'},
#              {'CreationDate': datetime.datetime(2024, 11, 13, 7, 55, 8, tzinfo=tzutc()),
#               'Name': 'kaki-udemy'},
#              {'CreationDate': datetime.datetime(2024, 11, 9, 23, 17, 33, tzinfo=tzutc()),
#               'Name': 'kaki-work-space'},
#              {'CreationDate': datetime.datetime(2024, 11, 13, 15, 20, 35, tzinfo=tzutc()),
#               'Name': 'profiles.spartaglobal.academy'},
#              {'CreationDate': datetime.datetime(2024, 10, 31, 7, 14, 55, tzinfo=tzutc()),
#               'Name': 'shahrukhterraformremotebackend'},
#              {'CreationDate': datetime.datetime(2024, 10, 31, 7, 35, 39, tzinfo=tzutc()),
#               'Name': 'sparta-backups'},
#              {'CreationDate': datetime.datetime(2024, 10, 31, 7, 35, 39, tzinfo=tzutc()),
#               'Name': 'sparta-cyber-bucket'},
#              {'CreationDate': datetime.datetime(2024, 11, 10, 9, 23, 30, tzinfo=tzutc()),
#               'Name': 'sparta-data'},
#              {'CreationDate': datetime.datetime(2024, 10, 31, 7, 35, 40, tzinfo=tzutc()),
#               'Name': 'sparta-example-state'},
#              {'CreationDate': datetime.datetime(2024, 11, 10, 9, 23, 30, tzinfo=tzutc()),
#               'Name': 'sparta-marketing'},
#              {'CreationDate': datetime.datetime(2024, 10, 26, 10, 4, 30, tzinfo=tzutc()),
#               'Name': 'sparta-media'},
#              {'CreationDate': datetime.datetime(2024, 11, 10, 9, 23, 30, tzinfo=tzutc()),
#               'Name': 'sparta-profiles'},
#              {'CreationDate': datetime.datetime(2024, 11, 10, 9, 23, 30, tzinfo=tzutc()),
#               'Name': 'sparta-terraform-state'},
#              {'CreationDate': datetime.datetime(2024, 10, 31, 8, 11, 43, tzinfo=tzutc()),
#               'Name': 'tech230-ramon1'},
#              {'CreationDate': datetime.datetime(2024, 11, 10, 12, 4, 46, tzinfo=tzutc()),
#               'Name': 'udemy-lab-streaming-data-rahul'}],
#  'Owner': {'ID': '21beecfeb5241d34bf1e52dca44fa8534c6be64dc3aa074ff430d8c6dd890040'},
#  'ResponseMetadata': {'HTTPHeaders': {'content-type': 'application/xml',
#                                       'date': 'Mon, 02 Jun 2025 16:56:25 GMT',
#                                       'server': 'AmazonS3',
#                                       'transfer-encoding': 'chunked',
#                                       'x-amz-id-2': '+5fv16qJtClsvrW2uak3QUjUN+DpCW8Vd28kzyQ5jcjIJXGKvhpOKMRW5aUHARh9E2i3gP8wYu4=',
#                                       'x-amz-request-id': 'NY7FVBAJVMFZDWJG'},
#                       'HTTPStatusCode': 200,
#                       'HostId': '+5fv16qJtClsvrW2uak3QUjUN+DpCW8Vd28kzyQ5jcjIJXGKvhpOKMRW5aUHARh9E2i3gP8wYu4=',
#                       'RequestId': 'NY7FVBAJVMFZDWJG',
#                       'RetryAttempts': 0}}
# assessment-dispatcher
# assessment-dispatcher-test
# assessmentbackup
# aws-logs-135928476890-eu-central-1
# bulk-policy-migration-135928476890
# cloudfuntest
# cyber10x-group1-bucket
# data-402-final-project
# data-eng-401-final-project
# data-eng-project-master
# data-eng-resources
# data-preassignment-alien-project-group1
# devops-bootcamp-shahrukh
# devops-content
# elasticbeanstalk-eu-west-1-135928476890
# emiledevopstest556373
# eng130-videos
# florina-hmrc-remote-backend
# graduate-market-analysis
# imc.spartaglobal.academy
# iotdatajoy2023
# jenkins-build-test
# kaki-udemy
# kaki-work-space
# profiles.spartaglobal.academy
# shahrukhterraformremotebackend
# sparta-backups
# sparta-cyber-bucket
# sparta-data
# sparta-example-state
# sparta-marketing
# sparta-media
# sparta-profiles
# sparta-terraform-state
# tech230-ramon1
# udemy-lab-streaming-data-rahul

# %% [markdown]
# ### LIST of the OBJECTS in the BUCKET data-eng-resources

# %% [markdown]
# `list_objects_v2` more recommended that `list_objects`

# %%
# Look inside the content of the bracket
bucket_name = 'data-eng-resources'
bucket_contents = s3_client.list_objects_v2(
    Bucket = bucket_name
    # more optionalargs
    # more args
)

pp.pprint(bucket_contents)
# Out:
# {'Contents': [{'ETag': '"bda64538cd4a8269836e4e09a787e93a"',
#                'Key': 'Data401/Brian_Luna.csv',
#                'LastModified': datetime.datetime(2024, 4, 4, 13, 56, 6, tzinfo=tzutc()),
#                'Size': 800,
#                'StorageClass': 'STANDARD'},
#               {'ETag': '"bda64538cd4a8269836e4e09a787e93a"',
#                'Key': 'Data401/Rahul.csv',
#                'LastModified': datetime.datetime(2024, 4, 5, 9, 46, 58, tzinfo=tzutc()),
#                'Size': 800,
#                'StorageClass': 'STANDARD'},
#               {'ETag': '"1df661b5d9c10b9264434fd252e08117"',
#                'Key': 'Data401/jack.csv',
#                'LastModified': datetime.datetime(2024, 3, 28, 17, 5, 18, tzinfo=tzutc()),
#                'Size': 857,
#                'StorageClass': 'STANDARD'},
#               {'ETag': '"959f10cc0c3aa461a8afaed9035b6f45"',
#                'Key': 'Data401/lihong.csv',
#                'LastModified': datetime.datetime(2024, 3, 29, 16, 9, 6, tzinfo=tzutc()),
#                'Size': 342,
#                'StorageClass': 'STANDARD'},
#               {'ETag': '"bda64538cd4a8269836e4e09a787e93a"',
#                'Key': 'Data401/muhammad.csv',
#                'LastModified': datetime.datetime(2024, 4, 3, 16, 6, 5, tzinfo=tzutc()),
#                'Size': 800,
#                'StorageClass': 'STANDARD'},
#               {'ETag': '"cf9ff2f93d509ae8502ba81b10d90081"',
#                'Key': 'Data401/rahul_csv.csv',
#                'LastModified': datetime.datetime(2024, 4, 4, 22, 56, 51, tzinfo=tzutc()),
#                'Size': 9801,
#                'StorageClass': 'STANDARD'},
#               {'ETag': '"218df503dfeef89f1f95a1d8d02c6292"',
#                'Key': 'Data401/robert.csv',
#                'LastModified': datetime.datetime(2024, 4, 2, 16, 19, 5, tzinfo=tzutc()),
#                'Size': 812,
#                'StorageClass': 'STANDARD'},
#               {'ETag': '"1df661b5d9c10b9264434fd252e08117"',
#                'Key': 'Data401/shivani.csv',
#                'LastModified': datetime.datetime(2024, 4, 3, 15, 10, 58, tzinfo=tzutc()),
#                'Size': 857,
#                'StorageClass': 'STANDARD'},
#               {'ETag': '"bda64538cd4a8269836e4e09a787e93a"',
#                'Key': 'Data401/shreya_jain.csv',
#                'LastModified': datetime.datetime(2024, 4, 1, 21, 24, 16, tzinfo=tzutc()),
#                'Size': 800,
#                'StorageClass': 'STANDARD'},
#               {'ETag': '"838ae2b7db44acb974d3d51004f28b95"',
#                'Key': 'Data401/usama.csv',
#                'LastModified': datetime.datetime(2024, 4, 3, 15, 0, 58, tzinfo=tzutc()),
#                'Size': 905,
#                'StorageClass': 'STANDARD'},
#               {'ETag': '"d41d8cd98f00b204e9800998ecf8427e"',
#                'Key': 'Data402/',
#                'LastModified': datetime.datetime(2024, 6, 3, 11, 13, 57, tzinfo=tzutc()),
#                'Size': 0,
#                'StorageClass': 'STANDARD'},
#               {'ETag': '"d41d8cd98f00b204e9800998ecf8427e"',
#                'Key': 'Data402/dataframes/',
#                'LastModified': datetime.datetime(2024, 6, 3, 13, 5, 31, tzinfo=tzutc()),
#                'Size': 0,
#                'StorageClass': 'STANDARD'},
#               {'ETag': '"a11d0040c19783979651dade17244687"',
#                'Key': 'Data402/dataframes/KR-details.csv',
#                'LastModified': datetime.datetime(2024, 6, 3, 15, 54, 22, tzinfo=tzutc()),
#                'Size': 38,
#                'StorageClass': 'STANDARD'},
#               {'ETag': '"a11d0040c19783979651dade17244687"',
#                'Key': 'Data402/dataframes/dafydd_dataframe.csv',
#                'LastModified': datetime.datetime(2024, 6, 3, 15, 15, 12, tzinfo=tzutc()),
#                'Size': 38,
#                'StorageClass': 'STANDARD'},
#               {'ETag': '"ec06af8ca1601aa1d64c45343c4afdbe"',
#                'Key': 'Data402/dataframes/dataframe_yoonhee.csv',
#                'LastModified': datetime.datetime(2024, 6, 3, 15, 48, 58, tzinfo=tzutc()),
#                'Size': 35,
#                'StorageClass': 'STANDARD'},
#               {'ETag': '"4aee40d04e5166e509e36b0aa42cf4d1"',
#                'Key': 'Data402/dataframes/happiness_yoonhee.csv',
#                'LastModified': datetime.datetime(2024, 6, 3, 15, 44, 2, tzinfo=tzutc()),
#                'Size': 8524,
#                'StorageClass': 'STANDARD'},
#               {'ETag': '"ec06af8ca1601aa1d64c45343c4afdbe"',
#                'Key': 'Data402/dataframes/jamesob-dataframe-upload.csv',
#                'LastModified': datetime.datetime(2024, 6, 3, 15, 31, 12, tzinfo=tzutc()),
#                'Size': 35,
#                'StorageClass': 'STANDARD'},
#               {'ETag': '"6ab1f7498ee0e5cdd0cde29223ef3a9e"',
#                'Key': 'Data402/dataframes/kyrun_dataframe.csv',
#                'LastModified': datetime.datetime(2024, 6, 3, 15, 28, 16, tzinfo=tzutc()),
#                'Size': 43,
#                'StorageClass': 'STANDARD'},
#               {'ETag': '"a11d0040c19783979651dade17244687"',
#                'Key': 'Data402/dataframes/luis_dataframe.csv',
#                'LastModified': datetime.datetime(2024, 6, 3, 15, 40, 53, tzinfo=tzutc()),
#                'Size': 38,
#                'StorageClass': 'STANDARD'},
#               {'ETag': '"a11d0040c19783979651dade17244687"',
#                'Key': 'Data402/dataframes/raj_dataframe.csv',
#                'LastModified': datetime.datetime(2024, 6, 3, 14, 52, 2, tzinfo=tzutc()),
#                'Size': 38,
#                'StorageClass': 'STANDARD'},
#               {'ETag': '"a11d0040c19783979651dade17244687"',
#                'Key': 'Data402/dataframes/sabrina_dataframe.csv',
#                'LastModified': datetime.datetime(2024, 6, 3, 15, 32, 42, tzinfo=tzutc()),
#                'Size': 38,
#                'StorageClass': 'STANDARD'},
#               {'ETag': '"0bc5338680eb69a1158dc06ca57a14b5"',
#                'Key': 'Data402/dataframes/sams_test_csvfile',
#                'LastModified': datetime.datetime(2024, 6, 3, 15, 35, 4, tzinfo=tzutc()),
#                'Size': 33,
#                'StorageClass': 'STANDARD'},
#               {'ETag': '"784169529f10fac5daf636ebe02207c3"',
#                'Key': 'Data402/fish-market-dafydd.csv',
#                'LastModified': datetime.datetime(2024, 6, 3, 15, 24, 1, tzinfo=tzutc()),
#                'Size': 746,
#                'StorageClass': 'STANDARD'},
#               {'ETag': '"bda64538cd4a8269836e4e09a787e93a"',
#                'Key': 'Data402/fish-market-raj.csv',
#                'LastModified': datetime.datetime(2024, 6, 3, 15, 2, 36, tzinfo=tzutc()),
#                'Size': 800,
#                'StorageClass': 'STANDARD'},
#               {'ETag': '"1b369bc131b497733fb73e4693302921"',
#                'Key': 'Data402/fish-market-sabrina.csv',
#                'LastModified': datetime.datetime(2024, 6, 4, 8, 29, 45, tzinfo=tzutc()),
#                'Size': 296,
#                'StorageClass': 'STANDARD'},
#               {'ETag': '"5114cf5dab069ee17bcc4443759b3332"',
#                'Key': 'Data402/fish_market_luis.csv',
#                'LastModified': datetime.datetime(2024, 6, 4, 8, 34, 9, tzinfo=tzutc()),
#                'Size': 160,
#                'StorageClass': 'STANDARD'},
#               {'ETag': '"d1bae75762fc0426d2ee16ec1ca9e190"',
#                'Key': 'Data402/fish_market_yoonhee.csv',
#                'LastModified': datetime.datetime(2024, 6, 3, 16, 28, 10, tzinfo=tzutc()),
#                'Size': 152,
#                'StorageClass': 'STANDARD'},
#               {'ETag': '"d41d8cd98f00b204e9800998ecf8427e"',
#                'Key': 'Data402/test/',
#                'LastModified': datetime.datetime(2024, 6, 3, 13, 0, 53, tzinfo=tzutc()),
#                'Size': 0,
#                'StorageClass': 'STANDARD'},
#               {'ETag': '"00eead6f4e210cefd2ff32cedcf51bd2"',
#                'Key': 'Data402/test/KR-details-dict.json',
#                'LastModified': datetime.datetime(2024, 6, 3, 14, 6, 41, tzinfo=tzutc()),
#                'Size': 40,
#                'StorageClass': 'STANDARD'},
#               {'ETag': '"d7d456b99121e72951e6b14c5e6b3f06"',
#                'Key': 'Data402/test/KR-details.json',
#                'LastModified': datetime.datetime(2024, 6, 3, 13, 55, 32, tzinfo=tzutc()),
#                'Size': 49,
#                'StorageClass': 'STANDARD'},
#               {'ETag': '"11c6ddfab0ee17df4ffcab9b75d204f5"',
#                'Key': 'Data402/test/dafyddl-details-dict.json',
#                'LastModified': datetime.datetime(2024, 6, 3, 14, 1, 40, tzinfo=tzutc()),
#                'Size': 37,
#                'StorageClass': 'STANDARD'},
#               {'ETag': '"9b10ddd13be133bf95e9a5a547919136"',
#                'Key': 'Data402/test/dafyddl-details.json',
#                'LastModified': datetime.datetime(2024, 6, 3, 13, 55, 23, tzinfo=tzutc()),
#                'Size': 25,
#                'StorageClass': 'STANDARD'},
#               {'ETag': '"8441865ce670963695f564f5b9dc2694"',
#                'Key': 'Data402/test/jacqueline-details-dict.json',
#                'LastModified': datetime.datetime(2024, 6, 3, 14, 4, 39, tzinfo=tzutc()),
#                'Size': 40,
#                'StorageClass': 'STANDARD'},
#               {'ETag': '"7ce034fe3eebf07298fc3dee70e99067"',
#                'Key': 'Data402/test/jacqueline-details.json',
#                'LastModified': datetime.datetime(2024, 6, 3, 13, 55, 13, tzinfo=tzutc()),
#                'Size': 41,
#                'StorageClass': 'STANDARD'},
#               {'ETag': '"f5af2ce611ff53f6c5e6b0ffd6c5a961"',
#                'Key': 'Data402/test/jameso-details-age.json',
#                'LastModified': datetime.datetime(2024, 6, 3, 14, 1, 19, tzinfo=tzutc()),
#                'Size': 30,
#                'StorageClass': 'STANDARD'},
#               {'ETag': '"4cd05f4c1e0bf82629951df4a5ccaef3"',
#                'Key': 'Data402/test/jamesob-details.json',
#                'LastModified': datetime.datetime(2024, 6, 3, 13, 55, 7, tzinfo=tzutc()),
#                'Size': 63,
#                'StorageClass': 'STANDARD'},
#               {'ETag': '"d41d8cd98f00b204e9800998ecf8427e"',
#                'Key': 'Data402/test/kehinde-details.json',
#                'LastModified': datetime.datetime(2024, 6, 3, 13, 58, 28, tzinfo=tzutc()),
#                'Size': 0,
#                'StorageClass': 'STANDARD'},
#               {'ETag': '"3ed61b26fa62e75597541752e1f2379d"',
#                'Key': 'Data402/test/kehinde-dict.json',
#                'LastModified': datetime.datetime(2024, 6, 3, 14, 2, 20, tzinfo=tzutc()),
#                'Size': 37,
#                'StorageClass': 'STANDARD'},
#               {'ETag': '"31a68b6b38fef2994fbcac41ba8ce57b"',
#                'Key': 'Data402/test/kyrunpl-details-dict.json',
#                'LastModified': datetime.datetime(2024, 6, 3, 14, 3, 7, tzinfo=tzutc()),
#                'Size': 37,
#                'StorageClass': 'STANDARD'},
#               {'ETag': '"a9358e3a6f0c8eff13ca1c29ed5b23e3"',
#                'Key': 'Data402/test/kyrunpl-details.json',
#                'LastModified': datetime.datetime(2024, 6, 3, 13, 57, 19, tzinfo=tzutc()),
#                'Size': 37,
#                'StorageClass': 'STANDARD'},
#               {'ETag': '"72bb550d52f060cb23c521d922a3bbc2"',
#                'Key': 'Data402/test/luis-details-dict.json',
#                'LastModified': datetime.datetime(2024, 6, 3, 14, 33, 56, tzinfo=tzutc()),
#                'Size': 34,
#                'StorageClass': 'STANDARD'},
#               {'ETag': '"0660c33113642232e72ee30866fba1a6"',
#                'Key': 'Data402/test/luis-details.json',
#                'LastModified': datetime.datetime(2024, 6, 3, 14, 46, 1, tzinfo=tzutc()),
#                'Size': 36,
#                'StorageClass': 'STANDARD'},
#               {'ETag': '"a11d0040c19783979651dade17244687"',
#                'Key': 'Data402/test/luis-trial',
#                'LastModified': datetime.datetime(2024, 6, 3, 15, 35, 52, tzinfo=tzutc()),
#                'Size': 38,
#                'StorageClass': 'STANDARD'},
#               {'ETag': '"9150ba9cc51b44fb9361e40addc04a12"',
#                'Key': 'Data402/test/lukef-details-dict.json',
#                'LastModified': datetime.datetime(2024, 6, 3, 14, 1, 16, tzinfo=tzutc()),
#                'Size': 35,
#                'StorageClass': 'STANDARD'},
#               {'ETag': '"4f5c5f6121fa9ca43c93ea87c6f17c24"',
#                'Key': 'Data402/test/lukef-details.json',
#                'LastModified': datetime.datetime(2024, 6, 3, 13, 54, 57, tzinfo=tzutc()),
#                'Size': 37,
#                'StorageClass': 'STANDARD'},
#               {'ETag': '"12d0b7e2d2cc086a575041079ed10cea"',
#                'Key': 'Data402/test/raja-details-dict.json',
#                'LastModified': datetime.datetime(2024, 6, 3, 14, 16, 15, tzinfo=tzutc()),
#                'Size': 34,
#                'StorageClass': 'STANDARD'},
#               {'ETag': '"ed3f469200601f75874cb539b5223774"',
#                'Key': 'Data402/test/raja-details.json',
#                'LastModified': datetime.datetime(2024, 6, 3, 14, 3, 25, tzinfo=tzutc()),
#                'Size': 40,
#                'StorageClass': 'STANDARD'},
#               {'ETag': '"85b7f7d86b6f36badc201bdad6957f98"',
#                'Key': 'Data402/test/sabrinak-details-dict.json',
#                'LastModified': datetime.datetime(2024, 6, 3, 14, 1, 22, tzinfo=tzutc()),
#                'Size': 38,
#                'StorageClass': 'STANDARD'},
#               {'ETag': '"ac5b0c14b0c63728b2846dc4f9df69b3"',
#                'Key': 'Data402/test/sabrinak-details.json',
#                'LastModified': datetime.datetime(2024, 6, 3, 13, 55, 4, tzinfo=tzutc()),
#                'Size': 39,
#                'StorageClass': 'STANDARD'},
#               {'ETag': '"0c98d3d19e15c708b5f19756100c2b65"',
#                'Key': 'Data402/test/sam_details_for_write',
#                'LastModified': datetime.datetime(2024, 6, 3, 13, 55, 12, tzinfo=tzutc()),
#                'Size': 36,
#                'StorageClass': 'STANDARD'},
#               {'ETag': '"9d081af467e369b1b5ddd6ae4fcc1ffc"',
#                'Key': 'Data402/test/sams-details-dict',
#                'LastModified': datetime.datetime(2024, 6, 3, 14, 1, 40, tzinfo=tzutc()),
#                'Size': 34,
#                'StorageClass': 'STANDARD'},
#               {'ETag': '"9c326703abcd7196dbde487ae68f4430"',
#                'Key': 'Data402/test/yoonhee-details-dict.json',
#                'LastModified': datetime.datetime(2024, 6, 3, 14, 2, 57, tzinfo=tzutc()),
#                'Size': 37,
#                'StorageClass': 'STANDARD'},
#               {'ETag': '"416537744cd45c6da1e81b54a53b746c"',
#                'Key': 'Data402/test/yoonhee_details.json',
#                'LastModified': datetime.datetime(2024, 6, 3, 13, 55, 59, tzinfo=tzutc()),
#                'Size': 38,
#                'StorageClass': 'STANDARD'},
#               {'ChecksumAlgorithm': ['CRC32'],
#                'ChecksumType': 'FULL_OBJECT',
#                'ETag': '"ffea335992c7ef84d301329fee23a9f2"',
#                'Key': 'Data502/fish/ahmed.csv',
#                'LastModified': datetime.datetime(2025, 6, 2, 14, 44, 48, tzinfo=tzutc()),
#                'Size': 74,
#                'StorageClass': 'STANDARD'},
#               {'ChecksumAlgorithm': ['CRC32'],
#                'ChecksumType': 'FULL_OBJECT',
#                'ETag': '"57465d57f583e0e76e9fdc31e99ffeec"',
#                'Key': 'Data502/fish/ahmed_fish_species_avg.csv',
#                'LastModified': datetime.datetime(2025, 6, 2, 14, 46, 45, tzinfo=tzutc()),
#                'Size': 56,
#                'StorageClass': 'STANDARD'},
#               {'ChecksumAlgorithm': ['CRC32'],
#                'ChecksumType': 'FULL_OBJECT',
#                'ETag': '"3889aeee4d11b40af6122da51890aa73"',
#                'Key': 'Data502/fish/rebecca',
#                'LastModified': datetime.datetime(2025, 6, 2, 14, 11, 23, tzinfo=tzutc()),
#                'Size': 1745,
#                'StorageClass': 'STANDARD'},
#               {'ChecksumAlgorithm': ['CRC32'],
#                'ChecksumType': 'FULL_OBJECT',
#                'ETag': '"3889aeee4d11b40af6122da51890aa73"',
#                'Key': 'Data502/fish/rebecca.csv',
#                'LastModified': datetime.datetime(2025, 6, 2, 14, 2, 47, tzinfo=tzutc()),
#                'Size': 1745,
#                'StorageClass': 'STANDARD'},
#               {'ETag': '"d41d8cd98f00b204e9800998ecf8427e"',
#                'Key': 'big-data-backup-do-not-use/',
#                'LastModified': datetime.datetime(2023, 3, 29, 15, 31, 23, tzinfo=tzutc()),
#                'Size': 0,
#                'StorageClass': 'STANDARD'},
#               {'ETag': '"d41d8cd98f00b204e9800998ecf8427e"',
#                'Key': 'big-data-backup-do-not-use/Adventure Works/',
#                'LastModified': datetime.datetime(2023, 3, 29, 15, 33, tzinfo=tzutc()),
#                'Size': 0,
#                'StorageClass': 'STANDARD'},
#               {'ETag': '"d8c92ff0aa20d97456b5d6065f2b7a5c"',
#                'Key': 'big-data-backup-do-not-use/Adventure '
#                       'Works/employees.csv',
#                'LastModified': datetime.datetime(2023, 3, 29, 15, 34, 51, tzinfo=tzutc()),
#                'Size': 45292,
#                'StorageClass': 'STANDARD'},
#               {'ETag': '"27599277a4b0408281ed65a811e815a4"',
#                'Key': 'big-data-backup-do-not-use/Adventure Works/people.csv',
#                'LastModified': datetime.datetime(2023, 3, 29, 15, 34, 50, tzinfo=tzutc()),
#                'Size': 4258503,
#                'StorageClass': 'STANDARD'},
#               {'ETag': '"a80fc9cab1c2a6cf81bc9f0696ac7aff"',
#                'Key': 'big-data-backup-do-not-use/Adventure '
#                       'Works/salespeople.csv',
#                'LastModified': datetime.datetime(2023, 3, 29, 15, 34, 48, tzinfo=tzutc()),
#                'Size': 2145,
#                'StorageClass': 'STANDARD'},
#               {'ETag': '"80857e124a1a1f8cbbaf7f92e6c8d98c"',
#                'Key': 'big-data-backup-do-not-use/Adventure '
#                       'Works/territories.csv',
#                'LastModified': datetime.datetime(2023, 3, 29, 15, 34, 47, tzinfo=tzutc()),
#                'Size': 1387,
#                'StorageClass': 'STANDARD'},
#               {'ETag': '"64aaac4a3729640b5b374db45ea79b0c"',
#                'Key': 'big-data-backup-do-not-use/CAT.csv',
#                'LastModified': datetime.datetime(2023, 3, 29, 15, 32, 37, tzinfo=tzutc()),
#                'Size': 18051,
#                'StorageClass': 'STANDARD'},
#               {'ETag': '"921f228078678565e1840edc026bffd5"',
#                'Key': 'big-data-backup-do-not-use/TSLA.csv',
#                'LastModified': datetime.datetime(2023, 3, 29, 15, 32, 37, tzinfo=tzutc()),
#                'Size': 17730,
#                'StorageClass': 'STANDARD'},
#               {'ETag': '"67fa6f5efdc100db4586aa80556e8620"',
#                'Key': 'big-data-backup-do-not-use/vgsales.csv',
#                'LastModified': datetime.datetime(2023, 9, 27, 14, 42, 22, tzinfo=tzutc()),
#                'Size': 1355781,
#                'StorageClass': 'STANDARD'},
#               {'ETag': '"d41d8cd98f00b204e9800998ecf8427e"',
#                'Key': 'big-data/',
#                'LastModified': datetime.datetime(2023, 3, 29, 15, 56, 49, tzinfo=tzutc()),
#                'Size': 0,
#                'StorageClass': 'STANDARD'},
#               {'ETag': '"d41d8cd98f00b204e9800998ecf8427e"',
#                'Key': 'big-data/Adventure Works/',
#                'LastModified': datetime.datetime(2023, 3, 29, 15, 57, 12, tzinfo=tzutc()),
#                'Size': 0,
#                'StorageClass': 'STANDARD'},
#               {'ETag': '"d8c92ff0aa20d97456b5d6065f2b7a5c"',
#                'Key': 'big-data/Adventure Works/employees.csv',
#                'LastModified': datetime.datetime(2023, 3, 29, 15, 57, 12, tzinfo=tzutc()),
#                'Size': 45292,
#                'StorageClass': 'STANDARD'},
#               {'ETag': '"27599277a4b0408281ed65a811e815a4"',
#                'Key': 'big-data/Adventure Works/people.csv',
#                'LastModified': datetime.datetime(2023, 3, 29, 15, 57, 12, tzinfo=tzutc()),
#                'Size': 4258503,
#                'StorageClass': 'STANDARD'},
#               {'ETag': '"a80fc9cab1c2a6cf81bc9f0696ac7aff"',
#                'Key': 'big-data/Adventure Works/salespeople.csv',
#                'LastModified': datetime.datetime(2023, 3, 29, 15, 57, 12, tzinfo=tzutc()),
#                'Size': 2145,
#                'StorageClass': 'STANDARD'},
#               {'ETag': '"80857e124a1a1f8cbbaf7f92e6c8d98c"',
#                'Key': 'big-data/Adventure Works/territories.csv',
#                'LastModified': datetime.datetime(2023, 3, 29, 15, 57, 12, tzinfo=tzutc()),
#                'Size': 1387,
#                'StorageClass': 'STANDARD'},
#               {'ETag': '"64aaac4a3729640b5b374db45ea79b0c"',
#                'Key': 'big-data/CAT.csv',
#                'LastModified': datetime.datetime(2023, 3, 29, 15, 57, 12, tzinfo=tzutc()),
#                'Size': 18051,
#                'StorageClass': 'STANDARD'},
#               {'ETag': '"921f228078678565e1840edc026bffd5"',
#                'Key': 'big-data/TSLA.csv',
#                'LastModified': datetime.datetime(2023, 3, 29, 15, 57, 12, tzinfo=tzutc()),
#                'Size': 17730,
#                'StorageClass': 'STANDARD'},
#               {'ETag': '"5a7cd113db9ff909f1c90b85b5c23d27"',
#                'Key': 'data-eng-resources/Data250/fish',
#                'LastModified': datetime.datetime(2024, 1, 5, 14, 20, 14, tzinfo=tzutc()),
#                'Size': 869,
#                'StorageClass': 'STANDARD'},
#               {'ChecksumAlgorithm': ['CRC32'],
#                'ChecksumType': 'FULL_OBJECT',
#                'ETag': '"d41d8cd98f00b204e9800998ecf8427e"',
#                'Key': 'data-eng-resources/Data502/fish',
#                'LastModified': datetime.datetime(2025, 6, 2, 14, 27, 31, tzinfo=tzutc()),
#                'Size': 0,
#                'StorageClass': 'STANDARD'},
#               {'ChecksumAlgorithm': ['CRC32'],
#                'ChecksumType': 'FULL_OBJECT',
#                'ETag': '"a076676f3af535f72d47620ad302a54a"',
#                'Key': 'data-eng-resources/Data502/fish/Shruthi.csv',
#                'LastModified': datetime.datetime(2025, 6, 2, 14, 38, 58, tzinfo=tzutc()),
#                'Size': 865,
#                'StorageClass': 'STANDARD'},
#               {'ChecksumAlgorithm': ['CRC32'],
#                'ChecksumType': 'FULL_OBJECT',
#                'ETag': '"798f1d9d9f2ba787de6e8051ecdcca09"',
#                'Key': 'data-eng-resources/Data502/fish/arabella.csv',
#                'LastModified': datetime.datetime(2025, 6, 2, 13, 48, 3, tzinfo=tzutc()),
#                'Size': 1008,
#                'StorageClass': 'STANDARD'},
#               {'ChecksumAlgorithm': ['CRC32'],
#                'ChecksumType': 'FULL_OBJECT',
#                'ETag': '"6bd11b88edb61737389db521e61287c8"',
#                'Key': 'data-eng-resources/Data502/fish/daniel-solomon.csv',
#                'LastModified': datetime.datetime(2025, 6, 2, 13, 48, 30, tzinfo=tzutc()),
#                'Size': 999,
#                'StorageClass': 'STANDARD'},
#               {'ChecksumAlgorithm': ['CRC32'],
#                'ChecksumType': 'FULL_OBJECT',
#                'ETag': '"cf7a9dfdb8c66aab6154d84e8f714d89"',
#                'Key': 'data-eng-resources/Data502/fish/daniel_c_fish.csv',
#                'LastModified': datetime.datetime(2025, 6, 2, 13, 50, 10, tzinfo=tzutc()),
#                'Size': 1008,
#                'StorageClass': 'STANDARD'},
#               {'ChecksumAlgorithm': ['CRC32'],
#                'ChecksumType': 'FULL_OBJECT',
#                'ETag': '"df39e9c61db88f55574679ab48ab5db0"',
#                'Key': 'data-eng-resources/Data502/fish/guilherme_fish.csv',
#                'LastModified': datetime.datetime(2025, 6, 2, 14, 11, 52, tzinfo=tzutc()),
#                'Size': 1023,
#                'StorageClass': 'STANDARD'},
#               {'ChecksumAlgorithm': ['CRC32'],
#                'ChecksumType': 'FULL_OBJECT',
#                'ETag': '"dbef3258cd72f27da70ee32761ffab14"',
#                'Key': 'data-eng-resources/Data502/fish/guney.csv',
#                'LastModified': datetime.datetime(2025, 6, 2, 14, 39, 30, tzinfo=tzutc()),
#                'Size': 1023,
#                'StorageClass': 'STANDARD'},
#               {'ChecksumAlgorithm': ['CRC32'],
#                'ChecksumType': 'FULL_OBJECT',
#                'ETag': '"f838517e583b4a2ba3870358f741a452"',
#                'Key': 'data-eng-resources/Data502/fish/hannah_df_fish.csv',
#                'LastModified': datetime.datetime(2025, 6, 2, 15, 12, 2, tzinfo=tzutc()),
#                'Size': 1018,
#                'StorageClass': 'STANDARD'},
#               {'ChecksumAlgorithm': ['CRC32'],
#                'ChecksumType': 'FULL_OBJECT',
#                'ETag': '"d41d8cd98f00b204e9800998ecf8427e"',
#                'Key': 'data-eng-resources/Data502/fish/hannah_fish.csv',
#                'LastModified': datetime.datetime(2025, 6, 2, 15, 8, 59, tzinfo=tzutc()),
#                'Size': 0,
#                'StorageClass': 'STANDARD'},
#               {'ChecksumAlgorithm': ['CRC32'],
#                'ChecksumType': 'FULL_OBJECT',
#                'ETag': '"b96ab8b8ca1ceb3c3d28711c54c479d2"',
#                'Key': 'data-eng-resources/Data502/fish/madalina_fish_df_data.csv',
#                'LastModified': datetime.datetime(2025, 6, 2, 14, 40, 9, tzinfo=tzutc()),
#                'Size': 1016,
#                'StorageClass': 'STANDARD'},
#               {'ChecksumAlgorithm': ['CRC32'],
#                'ChecksumType': 'FULL_OBJECT',
#                'ETag': '"a076676f3af535f72d47620ad302a54a"',
#                'Key': 'data-eng-resources/Data502/fish/mahlet.csv',
#                'LastModified': datetime.datetime(2025, 6, 2, 14, 59, 33, tzinfo=tzutc()),
#                'Size': 865,
#                'StorageClass': 'STANDARD'},
#               {'ChecksumAlgorithm': ['CRC32'],
#                'ChecksumType': 'FULL_OBJECT',
#                'ETag': '"dbef3258cd72f27da70ee32761ffab14"',
#                'Key': 'data-eng-resources/Data502/fish/saagar_fish.csv',
#                'LastModified': datetime.datetime(2025, 6, 2, 15, 47, 47, tzinfo=tzutc()),
#                'Size': 1023,
#                'StorageClass': 'STANDARD'},
#               {'ChecksumAlgorithm': ['CRC32'],
#                'ChecksumType': 'FULL_OBJECT',
#                'ETag': '"a076676f3af535f72d47620ad302a54a"',
#                'Key': 'data-eng-resources/Data502/fish/samatar.csv',
#                'LastModified': datetime.datetime(2025, 6, 2, 14, 12, 28, tzinfo=tzutc()),
#                'Size': 865,
#                'StorageClass': 'STANDARD'},
#               {'ChecksumAlgorithm': ['CRC32'],
#                'ChecksumType': 'FULL_OBJECT',
#                'ETag': '"d41d8cd98f00b204e9800998ecf8427e"',
#                'Key': 'data-eng-resources/Data502/hannah_fish.csv',
#                'LastModified': datetime.datetime(2025, 6, 2, 14, 29, 55, tzinfo=tzutc()),
#                'Size': 0,
#                'StorageClass': 'STANDARD'},
#               {'ChecksumAlgorithm': ['CRC32'],
#                'ChecksumType': 'FULL_OBJECT',
#                'ETag': '"dbef3258cd72f27da70ee32761ffab14"',
#                'Key': 'data-eng-resources/Data502/saagar_fish.csv',
#                'LastModified': datetime.datetime(2025, 6, 2, 15, 46, 37, tzinfo=tzutc()),
#                'Size': 1023,
#                'StorageClass': 'STANDARD'},
#               {'ChecksumAlgorithm': ['CRC32'],
#                'ChecksumType': 'FULL_OBJECT',
#                'ETag': '"3889aeee4d11b40af6122da51890aa73"',
#                'Key': 'fish/Data502/rebecca',
#                'LastModified': datetime.datetime(2025, 6, 2, 14, 26, 27, tzinfo=tzutc()),
#                'Size': 1745,
#                'StorageClass': 'STANDARD'},
#               {'ETag': '"d41d8cd98f00b204e9800998ecf8427e"',
#                'Key': 'python/',
#                'LastModified': datetime.datetime(2021, 3, 30, 7, 54, 22, tzinfo=tzutc()),
#                'Size': 0,
#                'StorageClass': 'STANDARD'},
#               {'ETag': '"30476b4ef881aec0c26eccb422414e6e"',
#                'Key': 'python/chatbot-intent.json',
#                'LastModified': datetime.datetime(2021, 3, 30, 7, 54, 22, tzinfo=tzutc()),
#                'Size': 69866,
#                'StorageClass': 'STANDARD'},
#               {'ETag': '"aa02eef2eae5d4e09bcd05e96bb58c51"',
#                'Key': 'python/fish-market-mon.csv',
#                'LastModified': datetime.datetime(2021, 3, 30, 7, 54, 22, tzinfo=tzutc()),
#                'Size': 12530,
#                'StorageClass': 'STANDARD'},
#               {'ETag': '"389918f10b963f3d835f265ba67e7597"',
#                'Key': 'python/fish-market-tues.csv',
#                'LastModified': datetime.datetime(2021, 3, 30, 7, 54, 22, tzinfo=tzutc()),
#                'Size': 12529,
#                'StorageClass': 'STANDARD'},
#               {'ETag': '"500c90abecca44a569bf1f23c717a6f5"',
#                'Key': 'python/fish-market.csv',
#                'LastModified': datetime.datetime(2021, 3, 30, 7, 54, 22, tzinfo=tzutc()),
#                'Size': 6022,
#                'StorageClass': 'STANDARD'},
#               {'ChecksumAlgorithm': ['CRC32'],
#                'ChecksumType': 'FULL_OBJECT',
#                'ETag': '"909cd107cb1b64fd75609e35f67c1faf"',
#                'Key': 'python/happiness-2019-copy.csv',
#                'LastModified': datetime.datetime(2025, 6, 2, 12, 58, 18, tzinfo=tzutc()),
#                'Size': 42,
#                'StorageClass': 'STANDARD'},
#               {'ETag': '"73596496f0c4654fd6ee4975f406bc56"',
#                'Key': 'python/happiness-2019.csv',
#                'LastModified': datetime.datetime(2021, 3, 30, 7, 54, 22, tzinfo=tzutc()),
#                'Size': 8822,
#                'StorageClass': 'STANDARD'},
#               {'ETag': '"d41d8cd98f00b204e9800998ecf8427e"',
#                'Key': 'vgsales/',
#                'LastModified': datetime.datetime(2023, 9, 28, 15, 13, tzinfo=tzutc()),
#                'Size': 0,
#                'StorageClass': 'STANDARD'},
#               {'ETag': '"67fa6f5efdc100db4586aa80556e8620"',
#                'Key': 'vgsales/vgsales.csv',
#                'LastModified': datetime.datetime(2023, 9, 28, 15, 13, 57, tzinfo=tzutc()),
#                'Size': 1355781,
#                'StorageClass': 'STANDARD'}],
#  'EncodingType': 'url',
#  'IsTruncated': False,
#  'KeyCount': 100,
#  'MaxKeys': 1000,
#  'Name': 'data-eng-resources',
#  'Prefix': '',
#  'ResponseMetadata': {'HTTPHeaders': {'content-type': 'application/xml',
#                                       'date': 'Mon, 02 Jun 2025 16:56:25 GMT',
#                                       'server': 'AmazonS3',
#                                       'transfer-encoding': 'chunked',
#                                       'x-amz-bucket-region': 'eu-central-1',
#                                       'x-amz-id-2': 'FKdgMF3N9o50ZvyhnDAOqdUkibaurEkshtb+18bn5mSaut6PZ1cnvlNzXDP381FzTwvwcOJZUx0uMyath6MnZbGL+rtdWMoLn27ipgmnMPM=',
#                                       'x-amz-request-id': 'NY76R0203PGJBZV5'},
#                       'HTTPStatusCode': 200,
#                       'HostId': 'FKdgMF3N9o50ZvyhnDAOqdUkibaurEkshtb+18bn5mSaut6PZ1cnvlNzXDP381FzTwvwcOJZUx0uMyath6MnZbGL+rtdWMoLn27ipgmnMPM=',
#                       'RequestId': 'NY76R0203PGJBZV5',
#                       'RetryAttempts': 0}}

# %%
#  List of all objects in the bucket whose key start with Data250/.
bucket_name = 'data-eng-resources'
data250_contents = s3_client.list_objects_v2(
    Bucket = bucket_name,
    Prefix = 'Data250/',   
    MaxKeys = 100,          # Optional
    Delimiter = '/'         # Optional
)

pp.pprint(bucket_contents)
# Out:
# {'Contents': [{'ETag': '"bda64538cd4a8269836e4e09a787e93a"',
#                'Key': 'Data401/Brian_Luna.csv',
#                'LastModified': datetime.datetime(2024, 4, 4, 13, 56, 6, tzinfo=tzutc()),
#                'Size': 800,
#                'StorageClass': 'STANDARD'},
#               {'ETag': '"bda64538cd4a8269836e4e09a787e93a"',
#                'Key': 'Data401/Rahul.csv',
#                'LastModified': datetime.datetime(2024, 4, 5, 9, 46, 58, tzinfo=tzutc()),
#                'Size': 800,
#                'StorageClass': 'STANDARD'},
#               {'ETag': '"1df661b5d9c10b9264434fd252e08117"',
#                'Key': 'Data401/jack.csv',
#                'LastModified': datetime.datetime(2024, 3, 28, 17, 5, 18, tzinfo=tzutc()),
#                'Size': 857,
#                'StorageClass': 'STANDARD'},
#               {'ETag': '"959f10cc0c3aa461a8afaed9035b6f45"',
#                'Key': 'Data401/lihong.csv',
#                'LastModified': datetime.datetime(2024, 3, 29, 16, 9, 6, tzinfo=tzutc()),
#                'Size': 342,
#                'StorageClass': 'STANDARD'},
#               {'ETag': '"bda64538cd4a8269836e4e09a787e93a"',
#                'Key': 'Data401/muhammad.csv',
#                'LastModified': datetime.datetime(2024, 4, 3, 16, 6, 5, tzinfo=tzutc()),
#                'Size': 800,
#                'StorageClass': 'STANDARD'},
#               {'ETag': '"cf9ff2f93d509ae8502ba81b10d90081"',
#                'Key': 'Data401/rahul_csv.csv',
#                'LastModified': datetime.datetime(2024, 4, 4, 22, 56, 51, tzinfo=tzutc()),
#                'Size': 9801,
#                'StorageClass': 'STANDARD'},
#               {'ETag': '"218df503dfeef89f1f95a1d8d02c6292"',
#                'Key': 'Data401/robert.csv',
#                'LastModified': datetime.datetime(2024, 4, 2, 16, 19, 5, tzinfo=tzutc()),
#                'Size': 812,
#                'StorageClass': 'STANDARD'},
#               {'ETag': '"1df661b5d9c10b9264434fd252e08117"',
#                'Key': 'Data401/shivani.csv',
#                'LastModified': datetime.datetime(2024, 4, 3, 15, 10, 58, tzinfo=tzutc()),
#                'Size': 857,
#                'StorageClass': 'STANDARD'},
#               {'ETag': '"bda64538cd4a8269836e4e09a787e93a"',
#                'Key': 'Data401/shreya_jain.csv',
#                'LastModified': datetime.datetime(2024, 4, 1, 21, 24, 16, tzinfo=tzutc()),
#                'Size': 800,
#                'StorageClass': 'STANDARD'},
#               {'ETag': '"838ae2b7db44acb974d3d51004f28b95"',
#                'Key': 'Data401/usama.csv',
#                'LastModified': datetime.datetime(2024, 4, 3, 15, 0, 58, tzinfo=tzutc()),
#                'Size': 905,
#                'StorageClass': 'STANDARD'},
#               {'ETag': '"d41d8cd98f00b204e9800998ecf8427e"',
#                'Key': 'Data402/',
#                'LastModified': datetime.datetime(2024, 6, 3, 11, 13, 57, tzinfo=tzutc()),
#                'Size': 0,
#                'StorageClass': 'STANDARD'},
#               {'ETag': '"d41d8cd98f00b204e9800998ecf8427e"',
#                'Key': 'Data402/dataframes/',
#                'LastModified': datetime.datetime(2024, 6, 3, 13, 5, 31, tzinfo=tzutc()),
#                'Size': 0,
#                'StorageClass': 'STANDARD'},
#               {'ETag': '"a11d0040c19783979651dade17244687"',
#                'Key': 'Data402/dataframes/KR-details.csv',
#                'LastModified': datetime.datetime(2024, 6, 3, 15, 54, 22, tzinfo=tzutc()),
#                'Size': 38,
#                'StorageClass': 'STANDARD'},
#               {'ETag': '"a11d0040c19783979651dade17244687"',
#                'Key': 'Data402/dataframes/dafydd_dataframe.csv',
#                'LastModified': datetime.datetime(2024, 6, 3, 15, 15, 12, tzinfo=tzutc()),
#                'Size': 38,
#                'StorageClass': 'STANDARD'},
#               {'ETag': '"ec06af8ca1601aa1d64c45343c4afdbe"',
#                'Key': 'Data402/dataframes/dataframe_yoonhee.csv',
#                'LastModified': datetime.datetime(2024, 6, 3, 15, 48, 58, tzinfo=tzutc()),
#                'Size': 35,
#                'StorageClass': 'STANDARD'},
#               {'ETag': '"4aee40d04e5166e509e36b0aa42cf4d1"',
#                'Key': 'Data402/dataframes/happiness_yoonhee.csv',
#                'LastModified': datetime.datetime(2024, 6, 3, 15, 44, 2, tzinfo=tzutc()),
#                'Size': 8524,
#                'StorageClass': 'STANDARD'},
#               {'ETag': '"ec06af8ca1601aa1d64c45343c4afdbe"',
#                'Key': 'Data402/dataframes/jamesob-dataframe-upload.csv',
#                'LastModified': datetime.datetime(2024, 6, 3, 15, 31, 12, tzinfo=tzutc()),
#                'Size': 35,
#                'StorageClass': 'STANDARD'},
#               {'ETag': '"6ab1f7498ee0e5cdd0cde29223ef3a9e"',
#                'Key': 'Data402/dataframes/kyrun_dataframe.csv',
#                'LastModified': datetime.datetime(2024, 6, 3, 15, 28, 16, tzinfo=tzutc()),
#                'Size': 43,
#                'StorageClass': 'STANDARD'},
#               {'ETag': '"a11d0040c19783979651dade17244687"',
#                'Key': 'Data402/dataframes/luis_dataframe.csv',
#                'LastModified': datetime.datetime(2024, 6, 3, 15, 40, 53, tzinfo=tzutc()),
#                'Size': 38,
#                'StorageClass': 'STANDARD'},
#               {'ETag': '"a11d0040c19783979651dade17244687"',
#                'Key': 'Data402/dataframes/raj_dataframe.csv',
#                'LastModified': datetime.datetime(2024, 6, 3, 14, 52, 2, tzinfo=tzutc()),
#                'Size': 38,
#                'StorageClass': 'STANDARD'},
#               {'ETag': '"a11d0040c19783979651dade17244687"',
#                'Key': 'Data402/dataframes/sabrina_dataframe.csv',
#                'LastModified': datetime.datetime(2024, 6, 3, 15, 32, 42, tzinfo=tzutc()),
#                'Size': 38,
#                'StorageClass': 'STANDARD'},
#               {'ETag': '"0bc5338680eb69a1158dc06ca57a14b5"',
#                'Key': 'Data402/dataframes/sams_test_csvfile',
#                'LastModified': datetime.datetime(2024, 6, 3, 15, 35, 4, tzinfo=tzutc()),
#                'Size': 33,
#                'StorageClass': 'STANDARD'},
#               {'ETag': '"784169529f10fac5daf636ebe02207c3"',
#                'Key': 'Data402/fish-market-dafydd.csv',
#                'LastModified': datetime.datetime(2024, 6, 3, 15, 24, 1, tzinfo=tzutc()),
#                'Size': 746,
#                'StorageClass': 'STANDARD'},
#               {'ETag': '"bda64538cd4a8269836e4e09a787e93a"',
#                'Key': 'Data402/fish-market-raj.csv',
#                'LastModified': datetime.datetime(2024, 6, 3, 15, 2, 36, tzinfo=tzutc()),
#                'Size': 800,
#                'StorageClass': 'STANDARD'},
#               {'ETag': '"1b369bc131b497733fb73e4693302921"',
#                'Key': 'Data402/fish-market-sabrina.csv',
#                'LastModified': datetime.datetime(2024, 6, 4, 8, 29, 45, tzinfo=tzutc()),
#                'Size': 296,
#                'StorageClass': 'STANDARD'},
#               {'ETag': '"5114cf5dab069ee17bcc4443759b3332"',
#                'Key': 'Data402/fish_market_luis.csv',
#                'LastModified': datetime.datetime(2024, 6, 4, 8, 34, 9, tzinfo=tzutc()),
#                'Size': 160,
#                'StorageClass': 'STANDARD'},
#               {'ETag': '"d1bae75762fc0426d2ee16ec1ca9e190"',
#                'Key': 'Data402/fish_market_yoonhee.csv',
#                'LastModified': datetime.datetime(2024, 6, 3, 16, 28, 10, tzinfo=tzutc()),
#                'Size': 152,
#                'StorageClass': 'STANDARD'},
#               {'ETag': '"d41d8cd98f00b204e9800998ecf8427e"',
#                'Key': 'Data402/test/',
#                'LastModified': datetime.datetime(2024, 6, 3, 13, 0, 53, tzinfo=tzutc()),
#                'Size': 0,
#                'StorageClass': 'STANDARD'},
#               {'ETag': '"00eead6f4e210cefd2ff32cedcf51bd2"',
#                'Key': 'Data402/test/KR-details-dict.json',
#                'LastModified': datetime.datetime(2024, 6, 3, 14, 6, 41, tzinfo=tzutc()),
#                'Size': 40,
#                'StorageClass': 'STANDARD'},
#               {'ETag': '"d7d456b99121e72951e6b14c5e6b3f06"',
#                'Key': 'Data402/test/KR-details.json',
#                'LastModified': datetime.datetime(2024, 6, 3, 13, 55, 32, tzinfo=tzutc()),
#                'Size': 49,
#                'StorageClass': 'STANDARD'},
#               {'ETag': '"11c6ddfab0ee17df4ffcab9b75d204f5"',
#                'Key': 'Data402/test/dafyddl-details-dict.json',
#                'LastModified': datetime.datetime(2024, 6, 3, 14, 1, 40, tzinfo=tzutc()),
#                'Size': 37,
#                'StorageClass': 'STANDARD'},
#               {'ETag': '"9b10ddd13be133bf95e9a5a547919136"',
#                'Key': 'Data402/test/dafyddl-details.json',
#                'LastModified': datetime.datetime(2024, 6, 3, 13, 55, 23, tzinfo=tzutc()),
#                'Size': 25,
#                'StorageClass': 'STANDARD'},
#               {'ETag': '"8441865ce670963695f564f5b9dc2694"',
#                'Key': 'Data402/test/jacqueline-details-dict.json',
#                'LastModified': datetime.datetime(2024, 6, 3, 14, 4, 39, tzinfo=tzutc()),
#                'Size': 40,
#                'StorageClass': 'STANDARD'},
#               {'ETag': '"7ce034fe3eebf07298fc3dee70e99067"',
#                'Key': 'Data402/test/jacqueline-details.json',
#                'LastModified': datetime.datetime(2024, 6, 3, 13, 55, 13, tzinfo=tzutc()),
#                'Size': 41,
#                'StorageClass': 'STANDARD'},
#               {'ETag': '"f5af2ce611ff53f6c5e6b0ffd6c5a961"',
#                'Key': 'Data402/test/jameso-details-age.json',
#                'LastModified': datetime.datetime(2024, 6, 3, 14, 1, 19, tzinfo=tzutc()),
#                'Size': 30,
#                'StorageClass': 'STANDARD'},
#               {'ETag': '"4cd05f4c1e0bf82629951df4a5ccaef3"',
#                'Key': 'Data402/test/jamesob-details.json',
#                'LastModified': datetime.datetime(2024, 6, 3, 13, 55, 7, tzinfo=tzutc()),
#                'Size': 63,
#                'StorageClass': 'STANDARD'},
#               {'ETag': '"d41d8cd98f00b204e9800998ecf8427e"',
#                'Key': 'Data402/test/kehinde-details.json',
#                'LastModified': datetime.datetime(2024, 6, 3, 13, 58, 28, tzinfo=tzutc()),
#                'Size': 0,
#                'StorageClass': 'STANDARD'},
#               {'ETag': '"3ed61b26fa62e75597541752e1f2379d"',
#                'Key': 'Data402/test/kehinde-dict.json',
#                'LastModified': datetime.datetime(2024, 6, 3, 14, 2, 20, tzinfo=tzutc()),
#                'Size': 37,
#                'StorageClass': 'STANDARD'},
#               {'ETag': '"31a68b6b38fef2994fbcac41ba8ce57b"',
#                'Key': 'Data402/test/kyrunpl-details-dict.json',
#                'LastModified': datetime.datetime(2024, 6, 3, 14, 3, 7, tzinfo=tzutc()),
#                'Size': 37,
#                'StorageClass': 'STANDARD'},
#               {'ETag': '"a9358e3a6f0c8eff13ca1c29ed5b23e3"',
#                'Key': 'Data402/test/kyrunpl-details.json',
#                'LastModified': datetime.datetime(2024, 6, 3, 13, 57, 19, tzinfo=tzutc()),
#                'Size': 37,
#                'StorageClass': 'STANDARD'},
#               {'ETag': '"72bb550d52f060cb23c521d922a3bbc2"',
#                'Key': 'Data402/test/luis-details-dict.json',
#                'LastModified': datetime.datetime(2024, 6, 3, 14, 33, 56, tzinfo=tzutc()),
#                'Size': 34,
#                'StorageClass': 'STANDARD'},
#               {'ETag': '"0660c33113642232e72ee30866fba1a6"',
#                'Key': 'Data402/test/luis-details.json',
#                'LastModified': datetime.datetime(2024, 6, 3, 14, 46, 1, tzinfo=tzutc()),
#                'Size': 36,
#                'StorageClass': 'STANDARD'},
#               {'ETag': '"a11d0040c19783979651dade17244687"',
#                'Key': 'Data402/test/luis-trial',
#                'LastModified': datetime.datetime(2024, 6, 3, 15, 35, 52, tzinfo=tzutc()),
#                'Size': 38,
#                'StorageClass': 'STANDARD'},
#               {'ETag': '"9150ba9cc51b44fb9361e40addc04a12"',
#                'Key': 'Data402/test/lukef-details-dict.json',
#                'LastModified': datetime.datetime(2024, 6, 3, 14, 1, 16, tzinfo=tzutc()),
#                'Size': 35,
#                'StorageClass': 'STANDARD'},
#               {'ETag': '"4f5c5f6121fa9ca43c93ea87c6f17c24"',
#                'Key': 'Data402/test/lukef-details.json',
#                'LastModified': datetime.datetime(2024, 6, 3, 13, 54, 57, tzinfo=tzutc()),
#                'Size': 37,
#                'StorageClass': 'STANDARD'},
#               {'ETag': '"12d0b7e2d2cc086a575041079ed10cea"',
#                'Key': 'Data402/test/raja-details-dict.json',
#                'LastModified': datetime.datetime(2024, 6, 3, 14, 16, 15, tzinfo=tzutc()),
#                'Size': 34,
#                'StorageClass': 'STANDARD'},
#               {'ETag': '"ed3f469200601f75874cb539b5223774"',
#                'Key': 'Data402/test/raja-details.json',
#                'LastModified': datetime.datetime(2024, 6, 3, 14, 3, 25, tzinfo=tzutc()),
#                'Size': 40,
#                'StorageClass': 'STANDARD'},
#               {'ETag': '"85b7f7d86b6f36badc201bdad6957f98"',
#                'Key': 'Data402/test/sabrinak-details-dict.json',
#                'LastModified': datetime.datetime(2024, 6, 3, 14, 1, 22, tzinfo=tzutc()),
#                'Size': 38,
#                'StorageClass': 'STANDARD'},
#               {'ETag': '"ac5b0c14b0c63728b2846dc4f9df69b3"',
#                'Key': 'Data402/test/sabrinak-details.json',
#                'LastModified': datetime.datetime(2024, 6, 3, 13, 55, 4, tzinfo=tzutc()),
#                'Size': 39,
#                'StorageClass': 'STANDARD'},
#               {'ETag': '"0c98d3d19e15c708b5f19756100c2b65"',
#                'Key': 'Data402/test/sam_details_for_write',
#                'LastModified': datetime.datetime(2024, 6, 3, 13, 55, 12, tzinfo=tzutc()),
#                'Size': 36,
#                'StorageClass': 'STANDARD'},
#               {'ETag': '"9d081af467e369b1b5ddd6ae4fcc1ffc"',
#                'Key': 'Data402/test/sams-details-dict',
#                'LastModified': datetime.datetime(2024, 6, 3, 14, 1, 40, tzinfo=tzutc()),
#                'Size': 34,
#                'StorageClass': 'STANDARD'},
#               {'ETag': '"9c326703abcd7196dbde487ae68f4430"',
#                'Key': 'Data402/test/yoonhee-details-dict.json',
#                'LastModified': datetime.datetime(2024, 6, 3, 14, 2, 57, tzinfo=tzutc()),
#                'Size': 37,
#                'StorageClass': 'STANDARD'},
#               {'ETag': '"416537744cd45c6da1e81b54a53b746c"',
#                'Key': 'Data402/test/yoonhee_details.json',
#                'LastModified': datetime.datetime(2024, 6, 3, 13, 55, 59, tzinfo=tzutc()),
#                'Size': 38,
#                'StorageClass': 'STANDARD'},
#               {'ChecksumAlgorithm': ['CRC32'],
#                'ChecksumType': 'FULL_OBJECT',
#                'ETag': '"ffea335992c7ef84d301329fee23a9f2"',
#                'Key': 'Data502/fish/ahmed.csv',
#                'LastModified': datetime.datetime(2025, 6, 2, 14, 44, 48, tzinfo=tzutc()),
#                'Size': 74,
#                'StorageClass': 'STANDARD'},
#               {'ChecksumAlgorithm': ['CRC32'],
#                'ChecksumType': 'FULL_OBJECT',
#                'ETag': '"57465d57f583e0e76e9fdc31e99ffeec"',
#                'Key': 'Data502/fish/ahmed_fish_species_avg.csv',
#                'LastModified': datetime.datetime(2025, 6, 2, 14, 46, 45, tzinfo=tzutc()),
#                'Size': 56,
#                'StorageClass': 'STANDARD'},
#               {'ChecksumAlgorithm': ['CRC32'],
#                'ChecksumType': 'FULL_OBJECT',
#                'ETag': '"3889aeee4d11b40af6122da51890aa73"',
#                'Key': 'Data502/fish/rebecca',
#                'LastModified': datetime.datetime(2025, 6, 2, 14, 11, 23, tzinfo=tzutc()),
#                'Size': 1745,
#                'StorageClass': 'STANDARD'},
#               {'ChecksumAlgorithm': ['CRC32'],
#                'ChecksumType': 'FULL_OBJECT',
#                'ETag': '"3889aeee4d11b40af6122da51890aa73"',
#                'Key': 'Data502/fish/rebecca.csv',
#                'LastModified': datetime.datetime(2025, 6, 2, 14, 2, 47, tzinfo=tzutc()),
#                'Size': 1745,
#                'StorageClass': 'STANDARD'},
#               {'ETag': '"d41d8cd98f00b204e9800998ecf8427e"',
#                'Key': 'big-data-backup-do-not-use/',
#                'LastModified': datetime.datetime(2023, 3, 29, 15, 31, 23, tzinfo=tzutc()),
#                'Size': 0,
#                'StorageClass': 'STANDARD'},
#               {'ETag': '"d41d8cd98f00b204e9800998ecf8427e"',
#                'Key': 'big-data-backup-do-not-use/Adventure Works/',
#                'LastModified': datetime.datetime(2023, 3, 29, 15, 33, tzinfo=tzutc()),
#                'Size': 0,
#                'StorageClass': 'STANDARD'},
#               {'ETag': '"d8c92ff0aa20d97456b5d6065f2b7a5c"',
#                'Key': 'big-data-backup-do-not-use/Adventure '
#                       'Works/employees.csv',
#                'LastModified': datetime.datetime(2023, 3, 29, 15, 34, 51, tzinfo=tzutc()),
#                'Size': 45292,
#                'StorageClass': 'STANDARD'},
#               {'ETag': '"27599277a4b0408281ed65a811e815a4"',
#                'Key': 'big-data-backup-do-not-use/Adventure Works/people.csv',
#                'LastModified': datetime.datetime(2023, 3, 29, 15, 34, 50, tzinfo=tzutc()),
#                'Size': 4258503,
#                'StorageClass': 'STANDARD'},
#               {'ETag': '"a80fc9cab1c2a6cf81bc9f0696ac7aff"',
#                'Key': 'big-data-backup-do-not-use/Adventure '
#                       'Works/salespeople.csv',
#                'LastModified': datetime.datetime(2023, 3, 29, 15, 34, 48, tzinfo=tzutc()),
#                'Size': 2145,
#                'StorageClass': 'STANDARD'},
#               {'ETag': '"80857e124a1a1f8cbbaf7f92e6c8d98c"',
#                'Key': 'big-data-backup-do-not-use/Adventure '
#                       'Works/territories.csv',
#                'LastModified': datetime.datetime(2023, 3, 29, 15, 34, 47, tzinfo=tzutc()),
#                'Size': 1387,
#                'StorageClass': 'STANDARD'},
#               {'ETag': '"64aaac4a3729640b5b374db45ea79b0c"',
#                'Key': 'big-data-backup-do-not-use/CAT.csv',
#                'LastModified': datetime.datetime(2023, 3, 29, 15, 32, 37, tzinfo=tzutc()),
#                'Size': 18051,
#                'StorageClass': 'STANDARD'},
#               {'ETag': '"921f228078678565e1840edc026bffd5"',
#                'Key': 'big-data-backup-do-not-use/TSLA.csv',
#                'LastModified': datetime.datetime(2023, 3, 29, 15, 32, 37, tzinfo=tzutc()),
#                'Size': 17730,
#                'StorageClass': 'STANDARD'},
#               {'ETag': '"67fa6f5efdc100db4586aa80556e8620"',
#                'Key': 'big-data-backup-do-not-use/vgsales.csv',
#                'LastModified': datetime.datetime(2023, 9, 27, 14, 42, 22, tzinfo=tzutc()),
#                'Size': 1355781,
#                'StorageClass': 'STANDARD'},
#               {'ETag': '"d41d8cd98f00b204e9800998ecf8427e"',
#                'Key': 'big-data/',
#                'LastModified': datetime.datetime(2023, 3, 29, 15, 56, 49, tzinfo=tzutc()),
#                'Size': 0,
#                'StorageClass': 'STANDARD'},
#               {'ETag': '"d41d8cd98f00b204e9800998ecf8427e"',
#                'Key': 'big-data/Adventure Works/',
#                'LastModified': datetime.datetime(2023, 3, 29, 15, 57, 12, tzinfo=tzutc()),
#                'Size': 0,
#                'StorageClass': 'STANDARD'},
#               {'ETag': '"d8c92ff0aa20d97456b5d6065f2b7a5c"',
#                'Key': 'big-data/Adventure Works/employees.csv',
#                'LastModified': datetime.datetime(2023, 3, 29, 15, 57, 12, tzinfo=tzutc()),
#                'Size': 45292,
#                'StorageClass': 'STANDARD'},
#               {'ETag': '"27599277a4b0408281ed65a811e815a4"',
#                'Key': 'big-data/Adventure Works/people.csv',
#                'LastModified': datetime.datetime(2023, 3, 29, 15, 57, 12, tzinfo=tzutc()),
#                'Size': 4258503,
#                'StorageClass': 'STANDARD'},
#               {'ETag': '"a80fc9cab1c2a6cf81bc9f0696ac7aff"',
#                'Key': 'big-data/Adventure Works/salespeople.csv',
#                'LastModified': datetime.datetime(2023, 3, 29, 15, 57, 12, tzinfo=tzutc()),
#                'Size': 2145,
#                'StorageClass': 'STANDARD'},
#               {'ETag': '"80857e124a1a1f8cbbaf7f92e6c8d98c"',
#                'Key': 'big-data/Adventure Works/territories.csv',
#                'LastModified': datetime.datetime(2023, 3, 29, 15, 57, 12, tzinfo=tzutc()),
#                'Size': 1387,
#                'StorageClass': 'STANDARD'},
#               {'ETag': '"64aaac4a3729640b5b374db45ea79b0c"',
#                'Key': 'big-data/CAT.csv',
#                'LastModified': datetime.datetime(2023, 3, 29, 15, 57, 12, tzinfo=tzutc()),
#                'Size': 18051,
#                'StorageClass': 'STANDARD'},
#               {'ETag': '"921f228078678565e1840edc026bffd5"',
#                'Key': 'big-data/TSLA.csv',
#                'LastModified': datetime.datetime(2023, 3, 29, 15, 57, 12, tzinfo=tzutc()),
#                'Size': 17730,
#                'StorageClass': 'STANDARD'},
#               {'ETag': '"5a7cd113db9ff909f1c90b85b5c23d27"',
#                'Key': 'data-eng-resources/Data250/fish',
#                'LastModified': datetime.datetime(2024, 1, 5, 14, 20, 14, tzinfo=tzutc()),
#                'Size': 869,
#                'StorageClass': 'STANDARD'},
#               {'ChecksumAlgorithm': ['CRC32'],
#                'ChecksumType': 'FULL_OBJECT',
#                'ETag': '"d41d8cd98f00b204e9800998ecf8427e"',
#                'Key': 'data-eng-resources/Data502/fish',
#                'LastModified': datetime.datetime(2025, 6, 2, 14, 27, 31, tzinfo=tzutc()),
#                'Size': 0,
#                'StorageClass': 'STANDARD'},
#               {'ChecksumAlgorithm': ['CRC32'],
#                'ChecksumType': 'FULL_OBJECT',
#                'ETag': '"a076676f3af535f72d47620ad302a54a"',
#                'Key': 'data-eng-resources/Data502/fish/Shruthi.csv',
#                'LastModified': datetime.datetime(2025, 6, 2, 14, 38, 58, tzinfo=tzutc()),
#                'Size': 865,
#                'StorageClass': 'STANDARD'},
#               {'ChecksumAlgorithm': ['CRC32'],
#                'ChecksumType': 'FULL_OBJECT',
#                'ETag': '"798f1d9d9f2ba787de6e8051ecdcca09"',
#                'Key': 'data-eng-resources/Data502/fish/arabella.csv',
#                'LastModified': datetime.datetime(2025, 6, 2, 13, 48, 3, tzinfo=tzutc()),
#                'Size': 1008,
#                'StorageClass': 'STANDARD'},
#               {'ChecksumAlgorithm': ['CRC32'],
#                'ChecksumType': 'FULL_OBJECT',
#                'ETag': '"6bd11b88edb61737389db521e61287c8"',
#                'Key': 'data-eng-resources/Data502/fish/daniel-solomon.csv',
#                'LastModified': datetime.datetime(2025, 6, 2, 13, 48, 30, tzinfo=tzutc()),
#                'Size': 999,
#                'StorageClass': 'STANDARD'},
#               {'ChecksumAlgorithm': ['CRC32'],
#                'ChecksumType': 'FULL_OBJECT',
#                'ETag': '"cf7a9dfdb8c66aab6154d84e8f714d89"',
#                'Key': 'data-eng-resources/Data502/fish/daniel_c_fish.csv',
#                'LastModified': datetime.datetime(2025, 6, 2, 13, 50, 10, tzinfo=tzutc()),
#                'Size': 1008,
#                'StorageClass': 'STANDARD'},
#               {'ChecksumAlgorithm': ['CRC32'],
#                'ChecksumType': 'FULL_OBJECT',
#                'ETag': '"df39e9c61db88f55574679ab48ab5db0"',
#                'Key': 'data-eng-resources/Data502/fish/guilherme_fish.csv',
#                'LastModified': datetime.datetime(2025, 6, 2, 14, 11, 52, tzinfo=tzutc()),
#                'Size': 1023,
#                'StorageClass': 'STANDARD'},
#               {'ChecksumAlgorithm': ['CRC32'],
#                'ChecksumType': 'FULL_OBJECT',
#                'ETag': '"dbef3258cd72f27da70ee32761ffab14"',
#                'Key': 'data-eng-resources/Data502/fish/guney.csv',
#                'LastModified': datetime.datetime(2025, 6, 2, 14, 39, 30, tzinfo=tzutc()),
#                'Size': 1023,
#                'StorageClass': 'STANDARD'},
#               {'ChecksumAlgorithm': ['CRC32'],
#                'ChecksumType': 'FULL_OBJECT',
#                'ETag': '"f838517e583b4a2ba3870358f741a452"',
#                'Key': 'data-eng-resources/Data502/fish/hannah_df_fish.csv',
#                'LastModified': datetime.datetime(2025, 6, 2, 15, 12, 2, tzinfo=tzutc()),
#                'Size': 1018,
#                'StorageClass': 'STANDARD'},
#               {'ChecksumAlgorithm': ['CRC32'],
#                'ChecksumType': 'FULL_OBJECT',
#                'ETag': '"d41d8cd98f00b204e9800998ecf8427e"',
#                'Key': 'data-eng-resources/Data502/fish/hannah_fish.csv',
#                'LastModified': datetime.datetime(2025, 6, 2, 15, 8, 59, tzinfo=tzutc()),
#                'Size': 0,
#                'StorageClass': 'STANDARD'},
#               {'ChecksumAlgorithm': ['CRC32'],
#                'ChecksumType': 'FULL_OBJECT',
#                'ETag': '"b96ab8b8ca1ceb3c3d28711c54c479d2"',
#                'Key': 'data-eng-resources/Data502/fish/madalina_fish_df_data.csv',
#                'LastModified': datetime.datetime(2025, 6, 2, 14, 40, 9, tzinfo=tzutc()),
#                'Size': 1016,
#                'StorageClass': 'STANDARD'},
#               {'ChecksumAlgorithm': ['CRC32'],
#                'ChecksumType': 'FULL_OBJECT',
#                'ETag': '"a076676f3af535f72d47620ad302a54a"',
#                'Key': 'data-eng-resources/Data502/fish/mahlet.csv',
#                'LastModified': datetime.datetime(2025, 6, 2, 14, 59, 33, tzinfo=tzutc()),
#                'Size': 865,
#                'StorageClass': 'STANDARD'},
#               {'ChecksumAlgorithm': ['CRC32'],
#                'ChecksumType': 'FULL_OBJECT',
#                'ETag': '"dbef3258cd72f27da70ee32761ffab14"',
#                'Key': 'data-eng-resources/Data502/fish/saagar_fish.csv',
#                'LastModified': datetime.datetime(2025, 6, 2, 15, 47, 47, tzinfo=tzutc()),
#                'Size': 1023,
#                'StorageClass': 'STANDARD'},
#               {'ChecksumAlgorithm': ['CRC32'],
#                'ChecksumType': 'FULL_OBJECT',
#                'ETag': '"a076676f3af535f72d47620ad302a54a"',
#                'Key': 'data-eng-resources/Data502/fish/samatar.csv',
#                'LastModified': datetime.datetime(2025, 6, 2, 14, 12, 28, tzinfo=tzutc()),
#                'Size': 865,
#                'StorageClass': 'STANDARD'},
#               {'ChecksumAlgorithm': ['CRC32'],
#                'ChecksumType': 'FULL_OBJECT',
#                'ETag': '"d41d8cd98f00b204e9800998ecf8427e"',
#                'Key': 'data-eng-resources/Data502/hannah_fish.csv',
#                'LastModified': datetime.datetime(2025, 6, 2, 14, 29, 55, tzinfo=tzutc()),
#                'Size': 0,
#                'StorageClass': 'STANDARD'},
#               {'ChecksumAlgorithm': ['CRC32'],
#                'ChecksumType': 'FULL_OBJECT',
#                'ETag': '"dbef3258cd72f27da70ee32761ffab14"',
#                'Key': 'data-eng-resources/Data502/saagar_fish.csv',
#                'LastModified': datetime.datetime(2025, 6, 2, 15, 46, 37, tzinfo=tzutc()),
#                'Size': 1023,
#                'StorageClass': 'STANDARD'},
#               {'ChecksumAlgorithm': ['CRC32'],
#                'ChecksumType': 'FULL_OBJECT',
#                'ETag': '"3889aeee4d11b40af6122da51890aa73"',
#                'Key': 'fish/Data502/rebecca',
#                'LastModified': datetime.datetime(2025, 6, 2, 14, 26, 27, tzinfo=tzutc()),
#                'Size': 1745,
#                'StorageClass': 'STANDARD'},
#               {'ETag': '"d41d8cd98f00b204e9800998ecf8427e"',
#                'Key': 'python/',
#                'LastModified': datetime.datetime(2021, 3, 30, 7, 54, 22, tzinfo=tzutc()),
#                'Size': 0,
#                'StorageClass': 'STANDARD'},
#               {'ETag': '"30476b4ef881aec0c26eccb422414e6e"',
#                'Key': 'python/chatbot-intent.json',
#                'LastModified': datetime.datetime(2021, 3, 30, 7, 54, 22, tzinfo=tzutc()),
#                'Size': 69866,
#                'StorageClass': 'STANDARD'},
#               {'ETag': '"aa02eef2eae5d4e09bcd05e96bb58c51"',
#                'Key': 'python/fish-market-mon.csv',
#                'LastModified': datetime.datetime(2021, 3, 30, 7, 54, 22, tzinfo=tzutc()),
#                'Size': 12530,
#                'StorageClass': 'STANDARD'},
#               {'ETag': '"389918f10b963f3d835f265ba67e7597"',
#                'Key': 'python/fish-market-tues.csv',
#                'LastModified': datetime.datetime(2021, 3, 30, 7, 54, 22, tzinfo=tzutc()),
#                'Size': 12529,
#                'StorageClass': 'STANDARD'},
#               {'ETag': '"500c90abecca44a569bf1f23c717a6f5"',
#                'Key': 'python/fish-market.csv',
#                'LastModified': datetime.datetime(2021, 3, 30, 7, 54, 22, tzinfo=tzutc()),
#                'Size': 6022,
#                'StorageClass': 'STANDARD'},
#               {'ChecksumAlgorithm': ['CRC32'],
#                'ChecksumType': 'FULL_OBJECT',
#                'ETag': '"909cd107cb1b64fd75609e35f67c1faf"',
#                'Key': 'python/happiness-2019-copy.csv',
#                'LastModified': datetime.datetime(2025, 6, 2, 12, 58, 18, tzinfo=tzutc()),
#                'Size': 42,
#                'StorageClass': 'STANDARD'},
#               {'ETag': '"73596496f0c4654fd6ee4975f406bc56"',
#                'Key': 'python/happiness-2019.csv',
#                'LastModified': datetime.datetime(2021, 3, 30, 7, 54, 22, tzinfo=tzutc()),
#                'Size': 8822,
#                'StorageClass': 'STANDARD'},
#               {'ETag': '"d41d8cd98f00b204e9800998ecf8427e"',
#                'Key': 'vgsales/',
#                'LastModified': datetime.datetime(2023, 9, 28, 15, 13, tzinfo=tzutc()),
#                'Size': 0,
#                'StorageClass': 'STANDARD'},
#               {'ETag': '"67fa6f5efdc100db4586aa80556e8620"',
#                'Key': 'vgsales/vgsales.csv',
#                'LastModified': datetime.datetime(2023, 9, 28, 15, 13, 57, tzinfo=tzutc()),
#                'Size': 1355781,
#                'StorageClass': 'STANDARD'}],
#  'EncodingType': 'url',
#  'IsTruncated': False,
#  'KeyCount': 100,
#  'MaxKeys': 1000,
#  'Name': 'data-eng-resources',
#  'Prefix': '',
#  'ResponseMetadata': {'HTTPHeaders': {'content-type': 'application/xml',
#                                       'date': 'Mon, 02 Jun 2025 16:56:25 GMT',
#                                       'server': 'AmazonS3',
#                                       'transfer-encoding': 'chunked',
#                                       'x-amz-bucket-region': 'eu-central-1',
#                                       'x-amz-id-2': 'FKdgMF3N9o50ZvyhnDAOqdUkibaurEkshtb+18bn5mSaut6PZ1cnvlNzXDP381FzTwvwcOJZUx0uMyath6MnZbGL+rtdWMoLn27ipgmnMPM=',
#                                       'x-amz-request-id': 'NY76R0203PGJBZV5'},
#                       'HTTPStatusCode': 200,
#                       'HostId': 'FKdgMF3N9o50ZvyhnDAOqdUkibaurEkshtb+18bn5mSaut6PZ1cnvlNzXDP381FzTwvwcOJZUx0uMyath6MnZbGL+rtdWMoLn27ipgmnMPM=',
#                       'RequestId': 'NY76R0203PGJBZV5',
#                       'RetryAttempts': 0}}

# %% [markdown]
# ### Print bucket names from CLIENT INTERFACE

# %%
for object in bucket_contents['Contents']:
    print(object['Key'])
# Out:
# Data401/Brian_Luna.csv
# Data401/Rahul.csv
# Data401/jack.csv
# Data401/lihong.csv
# Data401/muhammad.csv
# Data401/rahul_csv.csv
# Data401/robert.csv
# Data401/shivani.csv
# Data401/shreya_jain.csv
# Data401/usama.csv
# Data402/
# Data402/dataframes/
# Data402/dataframes/KR-details.csv
# Data402/dataframes/dafydd_dataframe.csv
# Data402/dataframes/dataframe_yoonhee.csv
# Data402/dataframes/happiness_yoonhee.csv
# Data402/dataframes/jamesob-dataframe-upload.csv
# Data402/dataframes/kyrun_dataframe.csv
# Data402/dataframes/luis_dataframe.csv
# Data402/dataframes/raj_dataframe.csv
# Data402/dataframes/sabrina_dataframe.csv
# Data402/dataframes/sams_test_csvfile
# Data402/fish-market-dafydd.csv
# Data402/fish-market-raj.csv
# Data402/fish-market-sabrina.csv
# Data402/fish_market_luis.csv
# Data402/fish_market_yoonhee.csv
# Data402/test/
# Data402/test/KR-details-dict.json
# Data402/test/KR-details.json
# Data402/test/dafyddl-details-dict.json
# Data402/test/dafyddl-details.json
# Data402/test/jacqueline-details-dict.json
# Data402/test/jacqueline-details.json
# Data402/test/jameso-details-age.json
# Data402/test/jamesob-details.json
# Data402/test/kehinde-details.json
# Data402/test/kehinde-dict.json
# Data402/test/kyrunpl-details-dict.json
# Data402/test/kyrunpl-details.json
# Data402/test/luis-details-dict.json
# Data402/test/luis-details.json
# Data402/test/luis-trial
# Data402/test/lukef-details-dict.json
# Data402/test/lukef-details.json
# Data402/test/raja-details-dict.json
# Data402/test/raja-details.json
# Data402/test/sabrinak-details-dict.json
# Data402/test/sabrinak-details.json
# Data402/test/sam_details_for_write
# Data402/test/sams-details-dict
# Data402/test/yoonhee-details-dict.json
# Data402/test/yoonhee_details.json
# Data502/fish/ahmed.csv
# Data502/fish/ahmed_fish_species_avg.csv
# Data502/fish/rebecca
# Data502/fish/rebecca.csv
# big-data-backup-do-not-use/
# big-data-backup-do-not-use/Adventure Works/
# big-data-backup-do-not-use/Adventure Works/employees.csv
# big-data-backup-do-not-use/Adventure Works/people.csv
# big-data-backup-do-not-use/Adventure Works/salespeople.csv
# big-data-backup-do-not-use/Adventure Works/territories.csv
# big-data-backup-do-not-use/CAT.csv
# big-data-backup-do-not-use/TSLA.csv
# big-data-backup-do-not-use/vgsales.csv
# big-data/
# big-data/Adventure Works/
# big-data/Adventure Works/employees.csv
# big-data/Adventure Works/people.csv
# big-data/Adventure Works/salespeople.csv
# big-data/Adventure Works/territories.csv
# big-data/CAT.csv
# big-data/TSLA.csv
# data-eng-resources/Data250/fish
# data-eng-resources/Data502/fish
# data-eng-resources/Data502/fish/Shruthi.csv
# data-eng-resources/Data502/fish/arabella.csv
# data-eng-resources/Data502/fish/daniel-solomon.csv
# data-eng-resources/Data502/fish/daniel_c_fish.csv
# data-eng-resources/Data502/fish/guilherme_fish.csv
# data-eng-resources/Data502/fish/guney.csv
# data-eng-resources/Data502/fish/hannah_df_fish.csv
# data-eng-resources/Data502/fish/hannah_fish.csv
# data-eng-resources/Data502/fish/madalina_fish_df_data.csv
# data-eng-resources/Data502/fish/mahlet.csv
# data-eng-resources/Data502/fish/saagar_fish.csv
# data-eng-resources/Data502/fish/samatar.csv
# data-eng-resources/Data502/hannah_fish.csv
# data-eng-resources/Data502/saagar_fish.csv
# fish/Data502/rebecca
# python/
# python/chatbot-intent.json
# python/fish-market-mon.csv
# python/fish-market-tues.csv
# python/fish-market.csv
# python/happiness-2019-copy.csv
# python/happiness-2019.csv
# vgsales/
# vgsales/vgsales.csv

# %%
#  List of all objects in the bucket whose key start with Python.
bucket_contents = s3_client.list_objects_v2(
    Bucket = bucket_name,
    Prefix = 'python'
)
pp.pprint(bucket_contents)
# Out:
# {'Contents': [{'ETag': '"d41d8cd98f00b204e9800998ecf8427e"',
#                'Key': 'python/',
#                'LastModified': datetime.datetime(2021, 3, 30, 7, 54, 22, tzinfo=tzutc()),
#                'Size': 0,
#                'StorageClass': 'STANDARD'},
#               {'ETag': '"30476b4ef881aec0c26eccb422414e6e"',
#                'Key': 'python/chatbot-intent.json',
#                'LastModified': datetime.datetime(2021, 3, 30, 7, 54, 22, tzinfo=tzutc()),
#                'Size': 69866,
#                'StorageClass': 'STANDARD'},
#               {'ETag': '"aa02eef2eae5d4e09bcd05e96bb58c51"',
#                'Key': 'python/fish-market-mon.csv',
#                'LastModified': datetime.datetime(2021, 3, 30, 7, 54, 22, tzinfo=tzutc()),
#                'Size': 12530,
#                'StorageClass': 'STANDARD'},
#               {'ETag': '"389918f10b963f3d835f265ba67e7597"',
#                'Key': 'python/fish-market-tues.csv',
#                'LastModified': datetime.datetime(2021, 3, 30, 7, 54, 22, tzinfo=tzutc()),
#                'Size': 12529,
#                'StorageClass': 'STANDARD'},
#               {'ETag': '"500c90abecca44a569bf1f23c717a6f5"',
#                'Key': 'python/fish-market.csv',
#                'LastModified': datetime.datetime(2021, 3, 30, 7, 54, 22, tzinfo=tzutc()),
#                'Size': 6022,
#                'StorageClass': 'STANDARD'},
#               {'ChecksumAlgorithm': ['CRC32'],
#                'ChecksumType': 'FULL_OBJECT',
#                'ETag': '"909cd107cb1b64fd75609e35f67c1faf"',
#                'Key': 'python/happiness-2019-copy.csv',
#                'LastModified': datetime.datetime(2025, 6, 2, 12, 58, 18, tzinfo=tzutc()),
#                'Size': 42,
#                'StorageClass': 'STANDARD'},
#               {'ETag': '"73596496f0c4654fd6ee4975f406bc56"',
#                'Key': 'python/happiness-2019.csv',
#                'LastModified': datetime.datetime(2021, 3, 30, 7, 54, 22, tzinfo=tzutc()),
#                'Size': 8822,
#                'StorageClass': 'STANDARD'}],
#  'EncodingType': 'url',
#  'IsTruncated': False,
#  'KeyCount': 7,
#  'MaxKeys': 1000,
#  'Name': 'data-eng-resources',
#  'Prefix': 'python',
#  'ResponseMetadata': {'HTTPHeaders': {'content-type': 'application/xml',
#                                       'date': 'Mon, 02 Jun 2025 16:56:25 GMT',
#                                       'server': 'AmazonS3',
#                                       'transfer-encoding': 'chunked',
#                                       'x-amz-bucket-region': 'eu-central-1',
#                                       'x-amz-id-2': '+B+bY4UDRSRimlvRZpUQETiYFSNPcBH8nOwGJ/O+8zifNt6AED9Itkp3OngXy90/jlbsp1cWBNi75m1it+JmyzH+KEPPwDh76SMjg4+GtPM=',
#                                       'x-amz-request-id': 'NY7BQQ1WZY1N8Z7N'},
#                       'HTTPStatusCode': 200,
#                       'HostId': '+B+bY4UDRSRimlvRZpUQETiYFSNPcBH8nOwGJ/O+8zifNt6AED9Itkp3OngXy90/jlbsp1cWBNi75m1it+JmyzH+KEPPwDh76SMjg4+GtPM=',
#                       'RequestId': 'NY7BQQ1WZY1N8Z7N',
#                       'RetryAttempts': 0}}

# %% [markdown]
# ### Use the boto3 RESOURCE interface to create a reference to a specific OBJECT (file) in a BUCKET in Amazon S3.

# %%
# Create a Bucket Object that has a method used to return its contents.
s3_resource = boto3.resource('s3')
bucket_name = 'data-eng-resources'

bucket = s3_resource.Bucket(bucket_name)
# print(bucket)

objects = bucket.objects
# print(objects)

contents = objects.all()
# print(contents)

for object in contents:
    print(object.key)
# Out:
# Data401/Brian_Luna.csv
# Data401/Rahul.csv
# Data401/jack.csv
# Data401/lihong.csv
# Data401/muhammad.csv
# Data401/rahul_csv.csv
# Data401/robert.csv
# Data401/shivani.csv
# Data401/shreya_jain.csv
# Data401/usama.csv
# Data402/
# Data402/dataframes/
# Data402/dataframes/KR-details.csv
# Data402/dataframes/dafydd_dataframe.csv
# Data402/dataframes/dataframe_yoonhee.csv
# Data402/dataframes/happiness_yoonhee.csv
# Data402/dataframes/jamesob-dataframe-upload.csv
# Data402/dataframes/kyrun_dataframe.csv
# Data402/dataframes/luis_dataframe.csv
# Data402/dataframes/raj_dataframe.csv
# Data402/dataframes/sabrina_dataframe.csv
# Data402/dataframes/sams_test_csvfile
# Data402/fish-market-dafydd.csv
# Data402/fish-market-raj.csv
# Data402/fish-market-sabrina.csv
# Data402/fish_market_luis.csv
# Data402/fish_market_yoonhee.csv
# Data402/test/
# Data402/test/KR-details-dict.json
# Data402/test/KR-details.json
# Data402/test/dafyddl-details-dict.json
# Data402/test/dafyddl-details.json
# Data402/test/jacqueline-details-dict.json
# Data402/test/jacqueline-details.json
# Data402/test/jameso-details-age.json
# Data402/test/jamesob-details.json
# Data402/test/kehinde-details.json
# Data402/test/kehinde-dict.json
# Data402/test/kyrunpl-details-dict.json
# Data402/test/kyrunpl-details.json
# Data402/test/luis-details-dict.json
# Data402/test/luis-details.json
# Data402/test/luis-trial
# Data402/test/lukef-details-dict.json
# Data402/test/lukef-details.json
# Data402/test/raja-details-dict.json
# Data402/test/raja-details.json
# Data402/test/sabrinak-details-dict.json
# Data402/test/sabrinak-details.json
# Data402/test/sam_details_for_write
# Data402/test/sams-details-dict
# Data402/test/yoonhee-details-dict.json
# Data402/test/yoonhee_details.json
# Data502/fish/ahmed.csv
# Data502/fish/ahmed_fish_species_avg.csv
# Data502/fish/rebecca
# Data502/fish/rebecca.csv
# big-data-backup-do-not-use/
# big-data-backup-do-not-use/Adventure Works/
# big-data-backup-do-not-use/Adventure Works/employees.csv
# big-data-backup-do-not-use/Adventure Works/people.csv
# big-data-backup-do-not-use/Adventure Works/salespeople.csv
# big-data-backup-do-not-use/Adventure Works/territories.csv
# big-data-backup-do-not-use/CAT.csv
# big-data-backup-do-not-use/TSLA.csv
# big-data-backup-do-not-use/vgsales.csv
# big-data/
# big-data/Adventure Works/
# big-data/Adventure Works/employees.csv
# big-data/Adventure Works/people.csv
# big-data/Adventure Works/salespeople.csv
# big-data/Adventure Works/territories.csv
# big-data/CAT.csv
# big-data/TSLA.csv
# data-eng-resources/Data250/fish
# data-eng-resources/Data502/fish
# data-eng-resources/Data502/fish/Shruthi.csv
# data-eng-resources/Data502/fish/arabella.csv
# data-eng-resources/Data502/fish/daniel-solomon.csv
# data-eng-resources/Data502/fish/daniel_c_fish.csv
# data-eng-resources/Data502/fish/guilherme_fish.csv
# data-eng-resources/Data502/fish/guney.csv
# data-eng-resources/Data502/fish/hannah_df_fish.csv
# data-eng-resources/Data502/fish/hannah_fish.csv
# data-eng-resources/Data502/fish/madalina_fish_df_data.csv
# data-eng-resources/Data502/fish/mahlet.csv
# data-eng-resources/Data502/fish/saagar_fish.csv
# data-eng-resources/Data502/fish/samatar.csv
# data-eng-resources/Data502/hannah_fish.csv
# data-eng-resources/Data502/saagar_fish.csv
# fish/Data502/rebecca
# python/
# python/chatbot-intent.json
# python/fish-market-mon.csv
# python/fish-market-tues.csv
# python/fish-market.csv
# python/happiness-2019-copy.csv
# python/happiness-2019.csv
# vgsales/
# vgsales/vgsales.csv
